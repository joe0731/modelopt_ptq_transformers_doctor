# %% [markdown]
# # modelopt PTQ ↔ vllm compatibility
#
# **modelopt** `0.44.0`  ·  **vllm** `0.6.0`–`0.11.0`  ·  **32** versions probed  ·  generated 2026-06-25
#
# All **32** stable releases in `0.6.0`–`0.11.0` were probed directly — yes/no determined by test, no inferred (N/A) cells.
#
# | symbols | compatible | never | signature drift ⚇ | dynamic | env errors |
# |:--:|:--:|:--:|:--:|:--:|:--:|
# | **7** | 1 | 6 | 0 | 3 | 20 |

# %% [markdown]
# ## Versions actually probed
# Bisection directly tested **32** of **32** stable releases in `0.6.0`–`0.11.0`. The compatible window is **inferred** from these samples — versions marked N/A below were **not** tested.
#
# **✓ probed:** `0.6.0`, `0.6.1`, `0.6.1.post1`, `0.6.1.post2`, `0.6.2`, `0.6.3`, `0.6.3.post1`, `0.6.4`, `0.6.4.post1`, `0.6.5`, `0.6.6`, `0.6.6.post1`, `0.7.0`, `0.7.1`, `0.7.2`, `0.7.3`, `0.8.0`, `0.8.1`, `0.8.2`, `0.8.3`, `0.8.4`, `0.8.5`, `0.8.5.post1`, `0.9.0`, `0.9.0.1`, `0.9.1`, `0.9.2`, `0.10.0`, `0.10.1`, `0.10.1.1`, `0.10.2`, `0.11.0`
#
# _All in-range releases were probed._

# %% [markdown]
# ## Per-symbol compatibility
#
# The **compatible window** is the authoritative result; **support** is 🟩 full · 🟨 partial · 🟥 never across probed versions.
#
# | symbol | role | compatible window (inferred) | support | |
# |---|---|---|:--:|:--:|
# | `vllm.attention.layers.cross_attention:CrossAttention` | quant | **never** | 🟥 |  |
# | `vllm.attention.layers.encoder_only_attention:EncoderOnlyAttention` | quant | **never** | 🟥 |  |
# | `vllm.distributed.parallel_state:get_dp_group` | quant | **never** | 🟥 |  |
# | `vllm.distributed.parallel_state:get_ep_group` | quant | **never** | 🟥 |  |
# | `vllm.distributed.parallel_state:get_tp_group` | quant | 0.6.0 – 0.6.6.post1 | 🟨 |  |
# | `vllm.model_executor.layers.attention.cross_attention:CrossAttention` | quant | **never** | 🟥 |  |
# | `vllm.model_executor.layers.attention.encoder_only_attention:EncoderOnlyAttention` | quant | **never** | 🟥 |  |

# %% [markdown]
# ## Support grid <sub>(by minor version)</sub>
#
# 🟩 yes · 🟨 partial / symbol missing · 🟥 no / module missing · ⬜ N/A
#
# | symbol | 0.6 | 0.7 | 0.8 | 0.9 | 0.10 | 0.11 |
# |---|:--:|:--:|:--:|:--:|:--:|:--:|
# | `vllm.attention.layers.cross_attention:CrossAttention` | 🟥 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `vllm.attention.layers.encoder_only_attention:EncoderOnlyAttention` | 🟥 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `vllm.distributed.parallel_state:get_dp_group` | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `vllm.distributed.parallel_state:get_ep_group` | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `vllm.distributed.parallel_state:get_tp_group` | 🟩 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `vllm.model_executor.layers.attention.cross_attention:CrossAttention` | 🟥 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `vllm.model_executor.layers.attention.encoder_only_attention:EncoderOnlyAttention` | 🟥 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |

# %% [markdown]
# ## ⚇ Signature changes
# *A symbol that still imports but whose signature changed within its window — the "imports fine, breaks at runtime" risk.*
#
# _No signature drift detected._

# %% [markdown]
# ## ✗ Never compatible
# *Architecture absent from this transformers range.*
#
# - `vllm.attention.layers.cross_attention:CrossAttention`
# - `vllm.attention.layers.encoder_only_attention:EncoderOnlyAttention`
# - `vllm.distributed.parallel_state:get_dp_group`
# - `vllm.distributed.parallel_state:get_ep_group`
# - `vllm.model_executor.layers.attention.cross_attention:CrossAttention`
# - `vllm.model_executor.layers.attention.encoder_only_attention:EncoderOnlyAttention`

# %% [markdown]
# <details><summary>3 dynamic registrations (runtime-discovered, not statically checkable)</summary>
#
# - `CrossAttention` — modelopt/torch/quantization/plugins/vllm.py:518
# - `EncoderOnlyAttention` — modelopt/torch/quantization/plugins/vllm.py:525
# - `VllmMLAAttention` — modelopt/torch/quantization/plugins/vllm.py:532
#
# </details>
