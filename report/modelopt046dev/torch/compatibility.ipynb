# %% [markdown]
# # modelopt PTQ ↔ torch compatibility
#
# **modelopt** `0.46.0.dev0`  ·  **torch** `2.1.0`–`2.12.1`  ·  **22** versions probed  ·  generated 2026-06-25
#
# All **22** stable releases in `2.1.0`–`2.12.1` were probed directly — yes/no determined by test, no inferred (N/A) cells.
#
# | symbols | compatible | never | signature drift ⚇ | dynamic | env errors |
# |:--:|:--:|:--:|:--:|:--:|:--:|
# | **61** | 57 | 4 | 4 | 17 | 3 |

# %% [markdown]
# ## Versions actually probed
# Bisection directly tested **22** of **22** stable releases in `2.1.0`–`2.12.1`. The compatible window is **inferred** from these samples — versions marked N/A below were **not** tested.
#
# **✓ probed:** `2.1.0`, `2.1.1`, `2.1.2`, `2.2.0`, `2.2.1`, `2.2.2`, `2.3.0`, `2.3.1`, `2.4.0`, `2.4.1`, `2.5.0`, `2.5.1`, `2.6.0`, `2.7.0`, `2.7.1`, `2.8.0`, `2.9.0`, `2.9.1`, `2.10.0`, `2.11.0`, `2.12.0`, `2.12.1`
#
# _All in-range releases were probed._

# %% [markdown]
# ## Per-symbol compatibility
#
# The **compatible window** is the authoritative result; **support** is 🟩 full · 🟨 partial · 🟥 never across probed versions.
#
# | symbol | role | compatible window (inferred) | support | |
# |---|---|---|:--:|:--:|
# | `torch.autograd:Function` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.compiler:is_compiling` | quant | 2.3.0 – 2.12.1 | 🟨 |  |
# | `torch.cuda:device` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.cuda:empty_cache` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.distributed.fsdp:FSDPModule` | export | 2.6.0 – 2.12.1 | 🟨 |  |
# | `torch.distributed.tensor:DTensor` | quant | 2.5.0 – 2.12.1 | 🟨 | ⚇ |
# | `torch.distributed.tensor:Shard` | quant | 2.5.0 – 2.12.1 | 🟨 | ⚇ |
# | `torch.nn.functional:linear` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.nn.functional:normalize` | export | 2.2.0 – 2.12.1 | 🟨 | ⚇ |
# | `torch.nn.functional:one_hot` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.nn:Linear` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.nn:Module` | export | 2.2.0 – 2.12.1 | 🟨 | ⚇ |
# | `torch.nn:Parameter` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.nn:Sequential` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.nn:functional` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch.onnx._globals:GLOBALS` | quant | 2.2.0 – 2.8.0 | 🟨 |  |
# | `torch.onnx._internal.torchscript_exporter._globals:GLOBALS` | quant | 2.9.0 – 2.12.1 | 🟨 |  |
# | `torch.ops.aten.bmm:out` | quant | **never** | 🟥 |  |
# | `torch.ops.aten:bmm` | quant | **never** | 🟥 |  |
# | `torch.ops.aten:matmul` | quant | **never** | 🟥 |  |
# | `torch:LongTensor` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:Size` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:Tensor` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:_matmul` | quant | **never** | 🟥 |  |
# | `torch:abs` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:all` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:any` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:bincount` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:bmm` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:cat` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:chunk` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:concat` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:device` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:dtype` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:empty` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:equal` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:finfo` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:float` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:float32` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:float8_e4m3fn` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:get_default_dtype` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:greater` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:int32` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:is_floating_point` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:isinf` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:isnan` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:long` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:max` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:mean` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:nan_to_num` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:nn` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:no_grad` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:ones` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:onnx` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:stack` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:tensor` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:topk` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:uint8` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:where` | quant | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:zeros` | export | 2.2.0 – 2.12.1 | 🟨 |  |
# | `torch:zeros_like` | quant | 2.2.0 – 2.12.1 | 🟨 |  |

# %% [markdown]
# ## Support grid <sub>(by minor version)</sub>
#
# 🟩 yes · 🟨 partial / symbol missing · 🟥 no / module missing · ⬜ N/A
#
# | symbol | 2.1 | 2.2 | 2.3 | 2.4 | 2.5 | 2.6 | 2.7 | 2.8 | 2.9 | 2.10 | 2.11 | 2.12 |
# |---|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|
# | `torch.autograd:Function` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.compiler:is_compiling` | 🟨 | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.cuda:device` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.cuda:empty_cache` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.distributed.fsdp:FSDPModule` | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.distributed.tensor:DTensor` | 🟨 | 🟨 | 🟨 | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.distributed.tensor:Shard` | 🟨 | 🟨 | 🟨 | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn.functional:linear` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn.functional:normalize` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn.functional:one_hot` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn:Linear` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn:Module` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn:Parameter` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn:Sequential` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.nn:functional` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.onnx._globals:GLOBALS` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟥 | 🟥 | 🟥 | 🟥 |
# | `torch.onnx._internal.torchscript_exporter._globals:GLOBALS` | 🟨 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch.ops.aten.bmm:out` | 🟨 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 |
# | `torch.ops.aten:bmm` | 🟨 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 |
# | `torch.ops.aten:matmul` | 🟨 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 | 🟥 |
# | `torch:LongTensor` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:Size` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:Tensor` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:_matmul` | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 | 🟨 |
# | `torch:abs` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:all` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:any` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:bincount` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:bmm` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:cat` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:chunk` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:concat` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:device` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:dtype` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:empty` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:equal` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:finfo` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:float` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:float32` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:float8_e4m3fn` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:get_default_dtype` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:greater` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:int32` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:is_floating_point` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:isinf` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:isnan` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:long` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:max` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:mean` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:nan_to_num` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:nn` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:no_grad` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:ones` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:onnx` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:stack` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:tensor` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:topk` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:uint8` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:where` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:zeros` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |
# | `torch:zeros_like` | 🟨 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 |

# %% [markdown]
# ## ⚇ Signature changes
# *A symbol that still imports but whose signature changed within its window — the "imports fine, breaks at runtime" risk.*
#
# **`torch.distributed.tensor:DTensor`**
# - `2.5.0 → 2.10.0` — **+2 −4 ~0** params (major rewrite)
#
# **`torch.distributed.tensor:Shard`**
# - `2.5.0 → 2.10.0` — `(dim: int) -> None` → `<no-signature>`
#
# **`torch.nn.functional:normalize`**
# - `2.2.0 → 2.12.0` — ~ `out: Optional[torch.Tensor] = None  →  out: torch.Tensor | None = None`
#
# **`torch.nn:Module`**
# - `2.2.0 → 2.10.0` — ~ `*args  →  *args: Any`; ~ `**kwargs  →  **kwargs: Any`

# %% [markdown]
# ## ✗ Never compatible
# *Architecture absent from this transformers range.*
#
# - `torch.ops.aten.bmm:out`
# - `torch.ops.aten:bmm`
# - `torch.ops.aten:matmul`
# - `torch:_matmul`

# %% [markdown]
# <details><summary>17 dynamic registrations (runtime-discovered, not statically checkable)</summary>
#
# - `HFColumnParallelLinear` — modelopt/torch/quantization/plugins/huggingface.py:414
# - `HFRowParallelLinear` — modelopt/torch/quantization/plugins/huggingface.py:419
# - `Llama4TextExperts` — modelopt/torch/quantization/plugins/huggingface.py:1199
# - `DbrxExperts` — modelopt/torch/quantization/plugins/huggingface.py:1209
# - `DbrxExpertGLU` — modelopt/torch/quantization/plugins/huggingface.py:1212
# - `DbrxFFN` — modelopt/torch/quantization/plugins/huggingface.py:1215
# - `FalconLinear` — modelopt/torch/quantization/plugins/huggingface.py:1223
# - `CompressedLinear` — modelopt/torch/quantization/plugins/huggingface.py:1231
# - `Qwen3VLMoeTextExperts` — modelopt/torch/quantization/plugins/huggingface.py:1241
# - `FP8Linear` — modelopt/torch/quantization/plugins/huggingface.py:1251
# - `GptOssExperts` — modelopt/torch/quantization/plugins/huggingface.py:1346
# - `moe_type` — modelopt/torch/quantization/plugins/huggingface.py:1360
# - `linear_type` — modelopt/torch/quantization/plugins/huggingface.py:1373
# - `mod_type` — modelopt/torch/quantization/plugins/huggingface.py:1436
# - `mod_type` — modelopt/torch/quantization/plugins/huggingface.py:1488
# - `moe_linear_type` — modelopt/torch/quantization/plugins/huggingface.py:1696
# - `original_cls` — modelopt/torch/quantization/conversion.py:623
#
# </details>
