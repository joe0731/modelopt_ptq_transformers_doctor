# %% [markdown]
# # modelopt PTQ ↔ transformers compatibility
#
# **modelopt** `0.46.0.dev0`  ·  **transformers** `4.46.0`–`5.10.4`  ·  **26** versions probed  ·  generated 2026-06-25
#
# **26** of 66 in-range releases were probed directly; the other **40** are N/A (not tested).
#
# | symbols | compatible | never | signature drift ⚇ | dynamic | env errors |
# |:--:|:--:|:--:|:--:|:--:|:--:|
# | **15** | 15 | 0 | 9 | 16 | 3 |

# %% [markdown]
# ## Versions actually probed
# Bisection directly tested **26** of **66** stable releases in `4.46.0`–`5.10.4`. The compatible window is **inferred** from these samples — versions marked N/A below were **not** tested.
#
# **✓ probed:** `4.46.0`, `4.48.2`, `4.48.3`, `4.49.0`, `4.50.2`, `4.50.3`, `4.51.0`, `4.51.2`, `4.53.1`, `4.53.2`, `4.54.0`, `4.54.1`, `4.55.0`, `4.55.1`, `4.55.4`, `4.56.1`, `4.56.2`, `4.57.0`, `4.57.5`, `5.5.1`, `5.6.1`, `5.8.1`, `5.10.0`, `5.10.1`, `5.10.2`, `5.10.4`
#
# **– N/A (not tested):** `4.46.1`, `4.46.2`, `4.46.3`, `4.47.0`, `4.47.1`, `4.48.0`, `4.48.1`, `4.50.0`, `4.50.1`, `4.51.1`, `4.51.3`, `4.52.0`, `4.52.1`, `4.52.2`, `4.52.3`, `4.52.4`, `4.53.0`, `4.53.3`, `4.55.2`, `4.55.3`, `4.56.0`, `4.57.1`, `4.57.2`, `4.57.3`, `4.57.4`, `4.57.6`, `5.0.0`, `5.1.0`, `5.2.0`, `5.3.0`, `5.4.0`, `5.5.0`, `5.5.2`, `5.5.3`, `5.5.4`, `5.6.0`, `5.6.2`, `5.7.0`, `5.8.0`, `5.9.0`

# %% [markdown]
# ## Per-symbol compatibility
#
# The **compatible window** is the authoritative result; **support** is 🟩 full · 🟨 partial · 🟥 never across probed versions.
#
# | symbol | role | compatible window (inferred) | support | |
# |---|---|---|:--:|:--:|
# | `transformers.activations:ACT2FN` | export | 4.46.0 – 5.10.0 | 🟨 |  |
# | `transformers.integrations.finegrained_fp8:FP8Linear` | quant | 4.49.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers.models.dbrx.modeling_dbrx:DbrxExpertGLU` | quant | 4.46.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers.models.dbrx.modeling_dbrx:DbrxExperts` | quant | 4.46.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers.models.dbrx.modeling_dbrx:DbrxFFN` | quant | 4.46.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers.models.falcon.modeling_falcon:FalconLinear` | quant | 4.46.0 – 5.10.0 | 🟨 |  |
# | `transformers.models.gpt_oss.modeling_gpt_oss:GptOssExperts` | quant | 4.55.0 – 5.10.0 | 🟨 |  |
# | `transformers.models.llama4.modeling_llama4:Llama4TextExperts` | quant | 4.51.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers.models.qwen3_vl_moe.modeling_qwen3_vl_moe:Qwen3VLMoeTextExperts` | quant | 4.57.0 – 5.10.0 | 🟨 |  |
# | `transformers.models.t5.modeling_t5:T5Attention` | quant | 4.46.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers.pytorch_utils:Conv1D` | quant | 4.46.0 – 5.10.0 | 🟨 |  |
# | `transformers:AutoConfig` | export | 4.46.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers:AutoFeatureExtractor` | export | 4.46.0 – 5.10.0 | 🟨 |  |
# | `transformers:PreTrainedModel` | quant | 4.46.0 – 5.10.0 | 🟨 | ⚇ |
# | `transformers:T5Config` | export | 4.46.0 – 5.10.0 | 🟨 | ⚇ |

# %% [markdown]
# ## Support grid <sub>(by minor version)</sub>
#
# 🟩 yes · 🟨 partial / symbol missing · 🟥 no / module missing · ⬜ N/A
#
# | symbol | 4.46 | 4.47 | 4.48 | 4.49 | 4.50 | 4.51 | 4.52 | 4.53 | 4.54 | 4.55 | 4.56 | 4.57 | 5.0 | 5.1 | 5.2 | 5.3 | 5.4 | 5.5 | 5.6 | 5.7 | 5.8 | 5.9 | 5.10 |
# |---|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|
# | `transformers.activations:ACT2FN` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.integrations.finegrained_fp8:FP8Linear` | 🟥 | ⬜ | 🟥 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.dbrx.modeling_dbrx:DbrxExpertGLU` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.dbrx.modeling_dbrx:DbrxExperts` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.dbrx.modeling_dbrx:DbrxFFN` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.falcon.modeling_falcon:FalconLinear` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.gpt_oss.modeling_gpt_oss:GptOssExperts` | 🟥 | ⬜ | 🟥 | 🟥 | 🟥 | 🟥 | ⬜ | 🟥 | 🟥 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.llama4.modeling_llama4:Llama4TextExperts` | 🟥 | ⬜ | 🟥 | 🟥 | 🟥 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.qwen3_vl_moe.modeling_qwen3_vl_moe:Qwen3VLMoeTextExperts` | 🟥 | ⬜ | 🟥 | 🟥 | 🟥 | 🟥 | ⬜ | 🟥 | 🟥 | 🟥 | 🟥 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.models.t5.modeling_t5:T5Attention` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers.pytorch_utils:Conv1D` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers:AutoConfig` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers:AutoFeatureExtractor` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers:PreTrainedModel` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |
# | `transformers:T5Config` | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | 🟩 | 🟩 | 🟩 | 🟩 | 🟩 | ⬜ | ⬜ | ⬜ | ⬜ | ⬜ | 🟩 | 🟩 | ⬜ | 🟩 | ⬜ | 🟨 |

# %% [markdown]
# ## ⚇ Signature changes
# *A symbol that still imports but whose signature changed within its window — the "imports fine, breaks at runtime" risk.*
#
# **`transformers.integrations.finegrained_fp8:FP8Linear`**
# - `4.49.0 → 4.53.1` — ~ `block_size: Optional[Tuple[int, int]] = None  →  block_size: Optional[tuple[int, int]] = None`
# - `4.53.1 → 5.5.1` — + `has_bias: bool = False`; − `bias: bool = False`; − `device=None`; ~ `block_size: Optional[tuple[int, int]] = None  →  block_size: tuple[int, int] | None = None`; ~ `activation_scheme='dynamic'  →  activation_scheme: str = 'dynamic'`; ~ `dtype=None  →  dtype=torch.float8_e4m3fn`
# - `5.5.1 → 5.8.1` — ~ `in_features: int  →  in_features: 'int'`; ~ `out_features: int  →  out_features: 'int'`; ~ `block_size: tuple[int, int] | None = None  →  block_size: 'tuple[int, int] | None' = None`; ~ `activation_scheme: str = 'dynamic'  →  activation_scheme: 'str' = 'dynamic'`; ~ `has_bias: bool = False  →  has_bias: 'bool' = False`
#
# **`transformers.models.dbrx.modeling_dbrx:DbrxExpertGLU`**
# - `4.46.0 → 5.5.1` — + `config`; − `hidden_size: int`; − `ffn_hidden_size: int`; − `moe_num_experts: int`; − `ffn_act_fn: dict`
#
# **`transformers.models.dbrx.modeling_dbrx:DbrxExperts`**
# - `4.46.0 → 5.5.1` — + `config`; − `hidden_size: int`; − `ffn_hidden_size: int`; − `moe_num_experts: int`; − `ffn_act_fn: dict`
#
# **`transformers.models.dbrx.modeling_dbrx:DbrxFFN`**
# - `4.46.0 → 5.5.1` — + `**kwargs`; ~ `config: transformers.models.dbrx.configuration_dbrx.DbrxConfig  →  config`
#
# **`transformers.models.llama4.modeling_llama4:Llama4TextExperts`**
# - `4.51.0 → 4.53.1` — ~ `config: transformers.models.llama4.configuration_llama4.Llama4Config  →  config: transformers.models.llama4.configuration_llama4.Llama4TextConfig`
#
# **`transformers.models.t5.modeling_t5:T5Attention`**
# - `4.46.0 → 5.5.1` — ~ `layer_idx: Optional[int] = None  →  layer_idx: int | None = None`
#
# **`transformers:AutoConfig`**
# - `4.46.0 → 4.53.1` — ↩ `return (none) → -> None`
#
# **`transformers:PreTrainedModel`**
# - `4.46.0 → 5.5.1` — ~ `config: transformers.configuration_utils.PretrainedConfig  →  config: transformers.configuration_utils.PreTrainedConfig`
#
# **`transformers:T5Config`**
# - `4.46.0 → 5.5.1` — **+11 −1 ~18** params (major rewrite)

# %% [markdown]
# ## ✗ Never compatible
# *Architecture absent from this transformers range.*
#
# _None._

# %% [markdown]
# <details><summary>16 dynamic registrations (runtime-discovered, not statically checkable)</summary>
#
# - `HFColumnParallelLinear` — modelopt/torch/quantization/plugins/huggingface.py:414
# - `HFRowParallelLinear` — modelopt/torch/quantization/plugins/huggingface.py:419
# - `Llama4TextExperts` — modelopt/torch/quantization/plugins/huggingface.py:1199
# - `DbrxExperts` — modelopt/torch/quantization/plugins/huggingface.py:1209
# - `DbrxExpertGLU` — modelopt/torch/quantization/plugins/huggingface.py:1212
# - `DbrxFFN` — modelopt/torch/quantization/plugins/huggingface.py:1215
# - `FalconLinear` — modelopt/torch/quantization/plugins/huggingface.py:1223
# - `CompressedLinear` — modelopt/torch/quantization/plugins/huggingface.py:1231
# - `Qwen3VLMoeTextExperts` — modelopt/torch/quantization/plugins/huggingface.py:1241
# - `FP8Linear` — modelopt/torch/quantization/plugins/huggingface.py:1251
# - `GptOssExperts` — modelopt/torch/quantization/plugins/huggingface.py:1346
# - `moe_type` — modelopt/torch/quantization/plugins/huggingface.py:1360
# - `linear_type` — modelopt/torch/quantization/plugins/huggingface.py:1373
# - `mod_type` — modelopt/torch/quantization/plugins/huggingface.py:1436
# - `mod_type` — modelopt/torch/quantization/plugins/huggingface.py:1488
# - `moe_linear_type` — modelopt/torch/quantization/plugins/huggingface.py:1696
#
# </details>
